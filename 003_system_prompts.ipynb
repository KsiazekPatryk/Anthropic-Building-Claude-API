# %%
messages = []

add_user_message(
    messages,
    "Write a Python function that checks a string for duplicate characters."
)
answer = chat(messages, system= "You are the Python engineer who writes very concise code.")

answer
